# %%
# Core
import numpy as np
import pandas as pd

# Tensorflow / ML
import tensorflow as tf
from tensorflow.python.keras import backend as K

# Plotting
import matplotlib.pyplot as plt
import matplotlib as mpl

# Utility
import time

# MSE Imports
import kepler_sieve
from asteroid_element import load_ast_elt
from candidate_element import asteroid_elts, perturb_elts, random_elts, elts_add_mixture_params, elts_add_H
from ztf_ast import load_ztf_nearest_ast, calc_hit_freq
from ztf_element import load_ztf_batch, make_ztf_batch, ztf_score_by_elt, ztf_elt_summary
from asteroid_model import AsteroidPosition, AsteroidDirection, make_model_ast_pos
from asteroid_search_layers import CandidateElements, TrajectoryScore
from asteroid_search_model import AsteroidSearchModel
from asteroid_search_report import traj_diff
from astro_utils import deg2dist, dist2deg, dist2sec

# %%
# Aliases
keras = tf.keras

# Constants
dtype = tf.float32
dtype_np = np.float32
space_dims = 3

# %%
# Set plot style variables
mpl.rcParams['figure.figsize'] = [16.0, 10.0]
mpl.rcParams['font.size'] = 16

# %% [markdown]
# ## Load ZTF Data and Batch of Orbital Elements

# %%
# Load orbital elements for known asteroids
ast_elt = load_ast_elt()

# Number of asteroids
N_ast = ast_elt.shape[0]

# %%
# Load ztf nearest asteroid data
ztf_ast = load_ztf_nearest_ast()

# %%
# Asteroid numbers and hit counts
ast_num, hit_count = calc_hit_freq(ztf=ztf_ast, thresh_sec=2.0)

# Sort the hit counts in descending order and find the top batch_size
idx = np.argsort(hit_count)[::-1]

# Extract the asteroid number and hit count for this batch
ast_num_best = ast_num[idx]
hit_count_best = hit_count[idx]

# %%
# Parameters to build elements batch
batch_size = 64

# Batch of unperturbed elements
elts_ast = asteroid_elts(ast_nums=ast_num_best[0:batch_size])

# %%
# # Review unperturbed elements
# elts_ast

# %%
# Selected elements
elts = elts_ast

# %% [markdown]
# ## Batches of ZTF Data vs. Elements

# %%
# Arguments to make_ztf_batch
thresh_deg = 2.0 / 3600.0
near_ast = True
regenerate = False

# %%
# Load unperturbed element batch
ztf_elt = load_ztf_batch(elts=elts, thresh_deg=thresh_deg, near_ast=near_ast, regenerate=regenerate)

# %%
# Score by element - unperturbed
score_by_elt = ztf_score_by_elt(ztf_elt)

# %%
# Summarize the ztf element batch: unperturbed asteroids
ztf_elt_summary(ztf_elt, score_by_elt, 'Unperturbed Asteroids')
# Out:
# ZTF Element Dataframe Unperturbed Asteroids:
#                   Total     (Per Batch)
# Observations   :    10333   (      161)
#
# Summarize score = sum(-1.0 - log(v)) by batch.  (Mean=0, Variance=num_obs)
# Mean score     :     159.76
# Sqrt(batch_obs):      12.71
# Mean t_score   :      12.61

# %%
# Mixture parameters
num_hits: int = 20
R_deg: float = 2.0 / 3600.0

# %%
# Add mixture parameters to candidate elements
elts_add_mixture_params(elts=elts, num_hits=num_hits, R_deg=R_deg, thresh_deg=thresh_deg)

# %%
# Add brightness parameter H
elts_add_H(elts=elts)

# %% [markdown]
# ## View Example DataFrames and Hits

# %%
# Review ztf_elt DataFrame
ztf_elt
# Out:
#         ztf_id  element_id         ObjectID          CandidateID  TimeStampID  \
# 0       341737         733  b'ZTF19abizrac'   937427766115015019        40797
# 1       345725         733  b'ZTF19abjajfg'   937467364815015020        40840
# 2       346522         733  b'ZTF19abjajmr'   937468726115015011        40842
# 3       347644         733  b'ZTF19abiyxiu'   937402264815015008        40777
# 4       431445         733  b'ZTF19abkkfhr'   934448315015015003        40221
# ...        ...         ...              ...                  ...          ...
# 10328  5447574      324582  b'ZTF20aapdfmj'  1145121244815015014        95204
# 10329  5450145      324582  b'ZTF20aapdfmj'  1145121716115015016        95205
# 10330  5461311      324582  b'ZTF20aapeobw'  1145164884815015018        95284
# 10331  5461312      324582  b'ZTF20aapeobw'  1145165336115015009        95285
# 10332  5569055      324582  b'ZTF20aaqiegi'  1149109466015015031        96104
#
#                 mjd         ra        dec    mag_app        ux  ...    elt_ux  \
# 0      58691.427766  33.130412  43.596186  17.784599  0.606481  ...  0.606486
# 1      58691.467361  33.148426  43.605278  18.220100  0.606265  ...  0.606270
# 2      58691.468727  33.149062  43.605587  18.129601  0.606257  ...  0.606263
# 3      58691.402269  33.118785  43.590288  17.705700  0.606621  ...  0.606626
# 4      58688.448310  31.751906  42.913068  17.974701  0.622775  ...  0.622780
# ...             ...        ...        ...        ...       ...  ...       ...
# 10328  58899.121250  42.392273  29.202629  18.231701  0.644677  ...  0.644680
# 10329  58899.121713  42.392439  29.202638  18.045900  0.644675  ...  0.644678
# 10330  58899.164884  42.405891  29.202386  18.825701  0.644538  ...  0.644541
# 10331  58899.165336  42.406082  29.202412  18.750099  0.644536  ...  0.644540
# 10332  58903.109468  43.677701  29.195480  18.884600  0.631356  ...  0.631360
#
#          elt_uy    elt_uz     elt_r         s     s_sec    z         v  \
# 0      0.637448  0.475220  2.115260  0.000007  1.509138  1.0  0.569375
# 1      0.637614  0.475274  2.114851  0.000007  1.479386  1.0  0.547145
# 2      0.637619  0.475276  2.114837  0.000007  1.503609  1.0  0.565210
# 3      0.637341  0.475186  2.115523  0.000007  1.491440  1.0  0.556098
# 4      0.624447  0.471393  2.145603  0.000007  1.493960  1.0  0.557979
# ...         ...       ...       ...       ...       ...  ...       ...
# 10328  0.734021  0.213544  2.915471  0.000005  0.934688  1.0  0.218410
# 10329  0.734022  0.213543  2.915477  0.000005  1.005771  1.0  0.252894
# 10330  0.734161  0.213479  2.916052  0.000004  0.890844  1.0  0.198401
# 10331  0.734163  0.213478  2.916058  0.000005  1.056357  1.0  0.278973
# 10332  0.747149  0.207734  2.967860  0.000005  1.017359  1.0  0.258755
#
#        is_hit  is_match
# 0        True     False
# 1        True     False
# 2        True     False
# 3        True     False
# 4        True     False
# ...       ...       ...
# 10328    True     False
# 10329    True     False
# 10330    True     False
# 10331    True     False
# 10332    True     False
#
# [10333 rows x 35 columns]

# %%
# Build numpy array of times
ts_np = ztf_elt.mjd.values.astype(dtype_np)

# Get observation count per element
row_lengths_np = ztf_elt.element_id.groupby(ztf_elt.element_id).count().values.astype(np.int32)

# %%
# Review results
element_id_best = ast_num_best[0]
mask = (ztf_elt.element_id == element_id_best)
hits_best = np.sum(ztf_elt[mask].is_hit)
hit_rate_best = np.mean(ztf_elt[mask].is_hit)
rows_best = np.sum(mask)
s_sec_min = np.min(ztf_elt[mask].s_sec)
idx = np.argmin(ztf_elt.s)
ztf_id = ztf_elt.ztf_id[idx]
# ztf_elt[mask].iloc[idx:idx+1]
print(f'Best asteroid has element_id = {element_id_best}')
print(f'Hit count: {hits_best} / {rows_best} observations')
print(f'Hit rate : {hit_rate_best:8.6f}')
print(f'Closest hit: {s_sec_min:0.3f} arc seconds')
# ztf_elt[mask]
# Out:
# Best asteroid has element_id = 51921
# Hit count: 158 / 158 observations
# Hit rate : 1.000000
# Closest hit: 0.381 arc seconds

# %% [markdown]
# ## Build Asteroid Search Model

# %%
# Observatory for ZTF data is Palomar Mountain
site_name = 'palomar'

# %%
# Training parameters
learning_rate = 2.0**-12
clipnorm = 1.0
save_at_end: bool = True

# %%
# Build asteroid search model
model = AsteroidSearchModel(
        elts=elts, ztf_elt=ztf_elt, 
        site_name=site_name, thresh_deg=thresh_deg, 
        learning_rate=learning_rate, clipnorm=clipnorm)

# %%
# Report summary outputs
model.report()
# Out:
# Good elements (hits >= 5):  64.00
#
#          \  log_like :  hits  :    R_sec : thresh_sec
# Mean Good:     3.36  :  99.23 :     1.00 :     2.00
# Mean Bad :      nan  :    nan :      nan :      nan
# Mean     :     3.36  :  99.23 :     1.00 :     2.00
# Median   :     3.05  : 100.00 :     1.00 :     2.00
# GeoMean  :     2.99  :  94.83 :     1.00 :     3.00
# Min      :    -8.21  :  33.00 :     1.00 :     2.00
# Max      :    11.49  : 150.00 :     1.00 :     2.00
# Trained for 0 batches over 0 epochs and 0 episodes (elapsed time 0 seconds).
# /home/michael/anaconda3/envs/kepler/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %%
# Freeze orbital elements; train only mixture parameters
model.freeze_candidate_elements()

# %%
# Load model
# model.load()

# %%
# Report summary outputs
# model.report()

# %%
# fig, ax = model_gold.plot_bar('hits', sorted=False)

# %% [markdown]
# ## Check that Predicted Direction Matches Expected Direction

# %%
model.recalibrate()

# %%
# Predicted position
q_pred, v_pred = model.predict_position()

# %%
# Expected position
cols_q = ['qx', 'qy', 'qz']
cols_v = ['vx', 'vy', 'vz']
q_true = ztf_elt[cols_q].values
v_true = ztf_elt[cols_v].values

# %%
# Difference between actual and predicted
dq = q_pred - q_true
dv = v_pred - v_true

q_err = np.linalg.norm(dq, axis=-1)
v_err = np.linalg.norm(dv, axis=-1)

q_err_rel = q_err / np.linalg.norm(q_true, axis=-1)
v_err_rel = v_err / np.linalg.norm(v_true, axis=-1)

q_err_mean = np.mean(q_err)
v_err_mean = np.mean(v_err)

q_err_rel_mean = np.mean(q_err_rel)
v_err_rel_mean = np.mean(v_err_rel)

print(f'Mean position error: {q_err_mean:6.2e} AU       ({q_err_rel_mean:6.2e} rel)')
print(f'Mean velocity error: {v_err_mean:6.2e} AU / day ({v_err_rel_mean:6.2e} rel)')
# Out:
# Mean position error: 1.15e-05 AU       (5.20e-06 rel)
# Mean velocity error: 5.77e-08 AU / day (4.71e-06 rel)

# %%
dq_cal = model.position.dq.numpy()
dv_cal = model.position.dv.numpy()

# %%
# Predicted direction
u_pred, r_pred, mag_pred = model.predict_direction()

# %%
# Expected direction
cols_u = ['elt_ux', 'elt_uy', 'elt_uz']
u_true = ztf_elt[cols_u].values

# %%
# Difference between actual and predicted
du = u_pred - u_true
u_err = np.linalg.norm(du, axis=-1)
u_err_sec = dist2sec(u_err)
u_err_mean = np.mean(u_err)
u_err_mean_sec = np.mean(u_err_sec)
print(f'Mean direction error: {u_err_mean:6.2e} Cartesian / {u_err_mean_sec:6.2f} arc seconds')
# Out:
# Mean direction error: 4.12e-06 Cartesian /   0.85 arc seconds

# %%
np.max(u_err_sec)
# Out:
# 3.5408127

# %%
cols_u_obs = ['ux', 'uy', 'uz']
u_obs = ztf_elt[cols_u_obs].values

# %%
du = u_pred - u_obs
u_diff = np.linalg.norm(du, axis=-1)
u_diff_sec = dist2sec(u_diff)
u_diff_mean = np.mean(u_diff)
u_diff_mean_sec = np.mean(u_diff_sec)
print(f'Mean direction diff: {u_diff_mean:6.2e} Cartesian / {u_diff_mean_sec:6.2f} arc seconds')
# Out:
# Mean direction diff: 5.08e-06 Cartesian /   1.05 arc seconds

# %%
np.max(u_diff_sec)
# Out:
# 5.3548026

# %%
# _ = model.position.dq.assign(np.zeros_like(dq_cal))
# _ = model.position.dv.assign(np.zeros_like(dv_cal))

# %%
model.sieve()
# Out:
# ********************************************************************************
# Round 1: 512 batches @ LR 2^-12 in mixture mode; thresh_sec_max = 7200.0
# ********************************************************************************
#
# Training episode 0: Epoch    0, Batch      0
# effective_learning_rate=2.441e-04, training_time 0 sec.
# Train on 4096 samples
# Epoch 1/4
# 4096/4096 [==============================] - 2s 582us/sample - loss: -61335247077376.0000
# Epoch 2/4
# 4096/4096 [==============================] - 1s 227us/sample - loss: -64530615959552.0000
# Epoch 3/4
# 4096/4096 [==============================] - 1s 222us/sample - loss: -67028081573888.0000
# Epoch 4/4
# 4096/4096 [==============================] - 1s 224us/sample - loss: -69583703441408.0000
# Adjusted element weight down on 64 candidate elements. Mean weight = 5.00e-01
# Increasing bad_episode_count to 1.
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 1: Epoch    4, Batch    256
# effective_learning_rate=1.221e-04, training_time 71 sec.
# Train on 4096 samples
# Epoch 5/8
# 4096/4096 [==============================] - 1s 226us/sample - loss: -30459596021760.0000
# Epoch 6/8
# 4096/4096 [==============================] - 1s 235us/sample - loss: -31487188238336.0000
# Epoch 7/8
# 4096/4096 [==============================] - 1s 235us/sample - loss: -32188324675584.0000
# Epoch 8/8
# 4096/4096 [==============================] - 1s 235us/sample - loss: -32943318138880.0000
# Adjusted element weight down on 64 candidate elements. Mean weight = 2.50e-01
# Increasing bad_episode_count to 2.
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# ********************************************************************************
# Terminating: Completed 512 batches.
# ********************************************************************************
#
# Good elements (hits >= 5):  64.00
#
#          \  log_like :  hits  :    R_sec : thresh_sec
# Mean Good:    12.29  : 137.80 :     1.00 :     2.00
# Mean Bad :      nan  :    nan :      nan :      nan
# Mean     :    12.29  : 137.80 :     1.00 :     2.00
# Median   :    12.32  : 138.00 :     1.00 :     2.00
# GeoMean  :    12.11  : 136.92 :     1.00 :     3.00
# Min      :     7.14  : 107.00 :     1.00 :     2.00
# Max      :    18.49  : 175.00 :     1.00 :     2.00
# Trained for 512 batches over 8 epochs and 2 episodes (elapsed time 75 seconds).
#
# ********************************************************************************
# Round 2: 2048 batches @ LR 2^-16 in joint mode.
# ********************************************************************************
# Applying learning_rate 1.53e-05 (2.0^-16.0) for adaptive training.
#
# Training episode 2: Epoch    8, Batch    512
# effective_learning_rate=6.104e-05, training_time 75 sec.
# Train on 4096 samples
# Epoch 9/12
# 4096/4096 [==============================] - 3s 701us/sample - loss: -3.0712
# Epoch 10/12
# 4096/4096 [==============================] - 1s 311us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 5.00e-01
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 3: Epoch   10, Batch    640
# effective_learning_rate=7.629e-06, training_time 79 sec.
# Train on 4096 samples
# Epoch 11/14
# 4096/4096 [==============================] - 1s 310us/sample - loss: -3.0712
# Epoch 12/14
# 4096/4096 [==============================] - 1s 314us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 2.50e-01
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 4: Epoch   12, Batch    768
# effective_learning_rate=3.815e-06, training_time 83 sec.
# Train on 4096 samples
# Epoch 13/16
# 4096/4096 [==============================] - 1s 313us/sample - loss: -3.0712
# Epoch 14/16
# 4096/4096 [==============================] - 1s 312us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 1.25e-01
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 5: Epoch   14, Batch    896
# effective_learning_rate=1.907e-06, training_time 86 sec.
# Train on 4096 samples
# Epoch 15/18
# 4096/4096 [==============================] - 1s 304us/sample - loss: -3.0712
# Epoch 16/18
# 4096/4096 [==============================] - 1s 283us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 6.25e-02
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 6: Epoch   16, Batch   1024
# effective_learning_rate=9.537e-07, training_time 90 sec.
# Train on 4096 samples
# Epoch 17/20
# 4096/4096 [==============================] - 1s 325us/sample - loss: -3.0712
# Epoch 18/20
# 4096/4096 [==============================] - 1s 335us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 3.12e-02
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 7: Epoch   18, Batch   1152
# effective_learning_rate=4.768e-07, training_time 93 sec.
# Train on 4096 samples
# Epoch 19/22
# 4096/4096 [==============================] - 1s 315us/sample - loss: -3.0712
# Epoch 20/22
# 4096/4096 [==============================] - 1s 303us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 1.56e-02
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 8: Epoch   20, Batch   1280
# effective_learning_rate=2.384e-07, training_time 97 sec.
# Train on 4096 samples
# Epoch 21/24
# 4096/4096 [==============================] - 1s 314us/sample - loss: -3.0712
# Epoch 22/24
# 4096/4096 [==============================] - 1s 305us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 7.81e-03
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 9: Epoch   22, Batch   1408
# effective_learning_rate=1.192e-07, training_time 100 sec.
# Train on 4096 samples
# Epoch 23/26
# 4096/4096 [==============================] - 1s 351us/sample - loss: -3.0712
# Epoch 24/26
# 4096/4096 [==============================] - 1s 336us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 3.91e-03
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# ********************************************************************************
# Terminating: Effective Learning Rate 5.960e-08 <= minimum 5.960e-08.
# ********************************************************************************
# Restoring original learning rate 2.44e-04.
#
# Good elements (hits >= 5):  64.00
#
#          \  log_like :  hits  :    R_sec : thresh_sec
# Mean Good:    12.29  : 137.80 :     1.00 :     2.00
# Mean Bad :      nan  :    nan :      nan :      nan
# Mean     :    12.29  : 137.80 :     1.00 :     2.00
# Median   :    12.32  : 138.00 :     1.00 :     2.00
# GeoMean  :    12.11  : 136.92 :     1.00 :     3.00
# Min      :     7.14  : 107.00 :     1.00 :     2.00
# Max      :    18.49  : 175.00 :     1.00 :     2.00
# Trained for 1536 batches over 24 epochs and 10 episodes (elapsed time 104 seconds).
#
# ********************************************************************************
# Round 3: 512 batches @ LR 2^-12 in mixture mode; thresh_sec_max = 5400.0
# ********************************************************************************
#
# Training episode 10: Epoch   24, Batch   1536
# effective_learning_rate=2.441e-04, training_time 104 sec.
# Train on 4096 samples
# Epoch 25/28
# 4096/4096 [==============================] - 2s 573us/sample - loss: -61354848813056.0000
# Epoch 26/28
# 4096/4096 [==============================] - 1s 266us/sample - loss: -64515713269760.0000
# Epoch 27/28
# 4096/4096 [==============================] - 1s 260us/sample - loss: -66994499944448.0000
# Epoch 28/28
# 4096/4096 [==============================] - 1s 257us/sample - loss: -69536335527936.0000
# Adjusted element weight down on 64 candidate elements. Mean weight = 5.00e-01
# Increasing bad_episode_count to 1.
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 11: Epoch   28, Batch   1792
# effective_learning_rate=1.221e-04, training_time 111 sec.
# Train on 4096 samples
# Epoch 29/32
# 4096/4096 [==============================] - 1s 258us/sample - loss: -30457614958592.0000
# Epoch 30/32
# 4096/4096 [==============================] - 1s 269us/sample - loss: -31483662696448.0000
# Epoch 31/32
# 4096/4096 [==============================] - 1s 270us/sample - loss: -32184056250368.0000
# Epoch 32/32
# 4096/4096 [==============================] - 1s 278us/sample - loss: -32937890119680.0000
# Adjusted element weight down on 64 candidate elements. Mean weight = 2.50e-01
# Increasing bad_episode_count to 2.
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# ********************************************************************************
# Terminating: Completed 2048 batches.
# ********************************************************************************
#
# Good elements (hits >= 5):  64.00
#
#          \  log_like :  hits  :    R_sec : thresh_sec
# Mean Good:    12.29  : 137.80 :     1.00 :     2.00
# Mean Bad :      nan  :    nan :      nan :      nan
# Mean     :    12.29  : 137.80 :     1.00 :     2.00
# Median   :    12.32  : 138.00 :     1.00 :     2.00
# GeoMean  :    12.11  : 136.92 :     1.00 :     3.00
# Min      :     7.14  : 107.00 :     1.00 :     2.00
# Max      :    18.49  : 175.00 :     1.00 :     2.00
# Trained for 2048 batches over 32 epochs and 12 episodes (elapsed time 116 seconds).
#
# ********************************************************************************
# Round 4: 2048 batches @ LR 2^-16 in joint mode.
# ********************************************************************************
# Applying learning_rate 1.53e-05 (2.0^-16.0) for adaptive training.
#
# Training episode 12: Epoch   32, Batch   2048
# effective_learning_rate=6.104e-05, training_time 116 sec.
# Train on 4096 samples
# Epoch 33/36
# 4096/4096 [==============================] - 3s 744us/sample - loss: -3.0712
# Epoch 34/36
# 4096/4096 [==============================] - 1s 329us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 1.95e-03
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# ********************************************************************************
# Terminating: Effective Learning Rate 2.980e-08 <= minimum 5.960e-08.
# ********************************************************************************
# Restoring original learning rate 2.44e-04.
#
# Good elements (hits >= 5):  64.00
#
#          \  log_like :  hits  :    R_sec : thresh_sec
# Mean Good:    12.29  : 137.80 :     1.00 :     2.00
# Mean Bad :      nan  :    nan :      nan :      nan
# Mean     :    12.29  : 137.80 :     1.00 :     2.00
# Median   :    12.32  : 138.00 :     1.00 :     2.00
# GeoMean  :    12.11  : 136.92 :     1.00 :     3.00
# Min      :     7.14  : 107.00 :     1.00 :     2.00
# Max      :    18.49  : 175.00 :     1.00 :     2.00
# Trained for 2176 batches over 34 epochs and 13 episodes (elapsed time 121 seconds).
#
# ********************************************************************************
# Round 5: 512 batches @ LR 2^-12 in mixture mode; thresh_sec_max = 3600.0
# ********************************************************************************
#
# Training episode 13: Epoch   34, Batch   2176
# effective_learning_rate=2.441e-04, training_time 121 sec.
# Train on 4096 samples
# Epoch 35/38
# 4096/4096 [==============================] - 2s 569us/sample - loss: -61353092988928.0000
# Epoch 36/38
# 4096/4096 [==============================] - 1s 291us/sample - loss: -64514668888064.0000
# Epoch 37/38
# 4096/4096 [==============================] - 1s 294us/sample - loss: -66994589335552.0000
# Epoch 38/38
# 4096/4096 [==============================] - 1s 292us/sample - loss: -69535888572416.0000
# Adjusted element weight down on 64 candidate elements. Mean weight = 5.00e-01
# Increasing bad_episode_count to 1.
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# Training episode 14: Epoch   38, Batch   2432
# effective_learning_rate=1.221e-04, training_time 128 sec.
# Train on 4096 samples
# Epoch 39/42
# 4096/4096 [==============================] - 1s 288us/sample - loss: -30456436064256.0000
# Epoch 40/42
# 4096/4096 [==============================] - 1s 291us/sample - loss: -31482617069568.0000
# Epoch 41/42
# 4096/4096 [==============================] - 1s 291us/sample - loss: -32184049696768.0000
# Epoch 42/42
# 4096/4096 [==============================] - 1s 296us/sample - loss: -32938210951168.0000
# Adjusted element weight down on 64 candidate elements. Mean weight = 2.50e-01
# Increasing bad_episode_count to 2.
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# ********************************************************************************
# Terminating: Completed 2688 batches.
# ********************************************************************************
#
# Good elements (hits >= 5):  64.00
#
#          \  log_like :  hits  :    R_sec : thresh_sec
# Mean Good:    12.29  : 137.80 :     1.00 :     2.00
# Mean Bad :      nan  :    nan :      nan :      nan
# Mean     :    12.29  : 137.80 :     1.00 :     2.00
# Median   :    12.32  : 138.00 :     1.00 :     2.00
# GeoMean  :    12.11  : 136.92 :     1.00 :     3.00
# Min      :     7.14  : 107.00 :     1.00 :     2.00
# Max      :    18.49  : 175.00 :     1.00 :     2.00
# Trained for 2688 batches over 42 epochs and 15 episodes (elapsed time 133 seconds).
#
# ********************************************************************************
# Round 6: 2048 batches @ LR 2^-16 in joint mode.
# ********************************************************************************
# Applying learning_rate 1.53e-05 (2.0^-16.0) for adaptive training.
#
# Training episode 15: Epoch   42, Batch   2688
# effective_learning_rate=6.104e-05, training_time 133 sec.
# Train on 4096 samples
# Epoch 43/46
# 4096/4096 [==============================] - 3s 753us/sample - loss: -3.0712
# Epoch 44/46
# 4096/4096 [==============================] - 1s 357us/sample - loss: 0.0000e+00
# Adjusted element weight down on 64 candidate elements. Mean weight = 9.77e-04
#                     \  All Elts : Bad Elts : Good Elts (64)
# Geom Mean Resolution:      1.00 :      nan :     1.00 arc seconds
# Geom Mean Threshold :      2.00 :      nan :     2.00 arc seconds
# Mean Log Likelihood :     12.29 :      nan :    12.29
# Mean Hits           :    137.80 :      nan :   137.80
# Good Elements       :     64.00
#
# ********************************************************************************
# Terminating: Effective Learning Rate 1.490e-08 <= minimum 5.960e-08.
# ********************************************************************************
# Restoring original learning rate 2.44e-04.
#
# Good elements (hits >= 5):  64.00
#
#          \  log_like :  hits  :    R_sec : thresh_sec
# Mean Good:    12.29  : 137.80 :     1.00 :     2.00
# Mean Bad :      nan  :    nan :      nan :      nan
# Mean     :    12.29  : 137.80 :     1.00 :     2.00
# Median   :    12.32  : 138.00 :     1.00 :     2.00
# GeoMean  :    12.11  : 136.92 :     1.00 :     3.00
# Min      :     7.14  : 107.00 :     1.00 :     2.00
# Max      :    18.49  : 175.00 :     1.00 :     2.00
# Trained for 2816 batches over 44 epochs and 16 episodes (elapsed time 138 seconds).
#
# ********************************************************************************
# Round 7: 512 batches @ LR 2^-12 in mixture mode; thresh_sec_max = 2400.0
# ********************************************************************************
#
# Training episode 16: Epoch   44, Batch   2816
# effective_learning_rate=2.441e-04, training_time 138 sec.
# Train on 4096 samples
# Epoch 45/48
